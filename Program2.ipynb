# %% [markdown]
# <a href="https://colab.research.google.com/github/Amartyaveer/ChatterBotter_Task/blob/master/Program2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retriving the data from Mongodb

# %%
# !pip install pymongo[srv]
import pymongo
from pymongo import MongoClient

# %%
cluster = MongoClient("mongodb+srv://Amartyaveer72:<password>@cluster0.qjtjq.mongodb.net/fetch_20newsgroups?retryWrites=true&w=majority")

# %%
db = cluster['fetch_20newsgroups']
collections = db['Noun']

# %%
nouns = collections.find({})

# %%
for i in nouns:
  print(i['name'])
# Out:
# Streaming output truncated to the last 5000 lines.
# fluorescent
# revere
# ballyhoo
# halon
# dwelling
# filename
# moore
# date
# computer
# photosynthesis
# cost
# obsession
# beef
# woodward
# muslim
# arrival
# boundary
# dive
# sump
# intentionality
# unrighteousness
# lint
# synagogue
# psalm
# challenge
# joke
# killing
# verne
# defense
# mobile
# donkey
# ticket
# hobbit
# utopia
# laugh
# wolverine
# streptococcus
# frying
# fruition
# gridlock
# engineering
# temperament
# weeds
# genealogy
# category
# dirk
# traveler
# sheep
# maniac
# vichy
# therapist
# hydrolysis
# garnet
# swelling
# differential
# thoroughness
# opiate
# july
# baseness
# gigabyte
# instruction
# overlook
# cough
# thrace
# smack
# enslavement
# calderon
# logging
# voicing
# greenbelt
# louisiana
# tinnitus
# meade
# volga
# fertilization
# spock
# nighthawk
# east
# while
# rating
# yellowcake
# shoddy
# buff
# sonata
# cartwright
# personal
# irenaeus
# tenderizer
# denomination
# iran
# ...
